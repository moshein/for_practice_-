# %%
for
# Out:
#   Cell In[8], line 1
#     for
#        ^
# SyntaxError: invalid syntax

# %%
class Human:
    def __init__(self, name, age, gender):
        self.name = name
        self.age = age
        self.gender = gender

    def eat(self, food):
        print(f"{self.name} is eating {food}")

    def sleep(self):
        print(f"{self.name} is sleeping.")

    def walk(self, where):
        print(f"{self.name} is walking towards {where}")

hekhek = Human("oshein", 26, "Female")

hekhek.eat("mangosteen")
# Out:
# oshein is eating mangosteen

# %% [markdown]
#                          Vehicle
#                  +----------------------+
#                  | +brand: String       |
#                  | +year: Int           |
#                  | +color: String       |
#                  |----------------------|
#                  | +start()             |
#                  | +stop()              |
#                  | +honk()              |
#                  +----------------------+
#                     /       |       \
#                    /        |        \
#                   /         |         \
#                  ↓          ↓          ↓
#
#               Car        Motorcycle       Bus
#         +-------------+ +-------------+ +-------------+
#         | +numDoors:  | | +hasSidecar:| | +capacity:  |
#         |   Int       | |   Boolean   | |   Int       |
#         |-------------| |-------------| |-------------|
#         | +drive()    | | +ride()     | | +openDoor() |
#         +-------------+ +-------------+ +-------------+

# %%
class Vehicle:
    def __init__(self, brand, year, color):
        self.brand = brand
        self.year = year
        self.color = color

    def start(self):
        print("the vehicle is starting")

    def stop(self):
        print("the vehicle is stopping")

    def honk(self):
        print("honk honkk!!")

class Car:
    def __init__(self, brand, year, color, numDoors):
        super().__init__(brand, year, color)
        self.numDoors = numDoors

    def drive(self):
        print("the vehicle is driving")

class Motorcycle:
    def __init__(self, brand, year, color, hasSideCar):
        super().__init__(brand, year, color)
        self.hasSideCar = hasSideCar

    def ride(self):
        print("the vehicle is now riding")

class Bus:
    def __init__(self, brand, year, color, capacity):
        super().__init__(brand, year, color)
        self.capacity = capacity

    def openDoor(self):
        print("the bus door is opened hekhek")

carVroom = Car("toyota", "yes", "pink", "yes")

carVroom.drive()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 40
#      36
#      37     def openDoor(self):
#      38         print("the bus door is opened hekhek")
#      39
# ---> 40 carVroom = Car("toyota", "yes", "pink", "yes")
#      41
#      42 carVroom.drive()
#
# Cell In[15], line 18, in Car.__init__(self, brand, year, color, numDoors)
#      17     def __init__(self, brand, year, color, numDoors):
# ---> 18         super().__init__(brand, year, color)
#      19         self.numDoors = numDoors
#
# TypeError: object.__init__() takes exactly one argument (the instance to initialize)

# %%
class Vehicle:
    def __init__(self, brand, year, color):
        self.brand = brand
        self.year = year
        self.color = color

    def start(self):
        print("the vehicle is starting")

    def stop(self):
        print("the vehicle is stopping")

    def honk(self):
        print("honk honkk!!")

class Car(Vehicle):
    def __init__(self, brand, year, color, numDoors):
        super().__init__(brand, year, color)
        self.numDoors = numDoors

    def drive(self):
        print("the vehicle is driving")

class Motorcycle(Vehicle):
    def __init__(self, brand, year, color, hasSideCar):
        super().__init__(brand, year, color)
        self.hasSideCar = hasSideCar

    def ride(self):
        print("the vehicle is now riding")

class Bus(Vehicle):
    def __init__(self, brand, year, color, capacity):
        super().__init__(brand, year, color)
        self.capacity = capacity

    def openDoor(self):
        print("the bus door is opened hekhek")

carVroom = Car("toyota", "yes", "pink", "yes")

carVroom.honk() ## ma-inherit diay gyapon niya ang mga methods from Vehicle Class
# Out:
# honk honkk!!

# %%
class Employee:
    def __init__(self, name, age, salary):
        self.name = name
        self.age = age
        self.salary = salary

    def work(self):
        print(f"{self.name} is working")

    def takeBreak(self):
        print(f"{self.name} is taking a break")

class Developer(Employee):
    def __init__(self, name, age, salary, language):
        super().__init__(name, age, salary)
        self.language = language

    def code(self):
        print(f"{self.name} is coding *taktaktaktaktak*")

class Designer(Employee):
    def __init__(self, name, age, salary, tool):
        super().__init__(name, age, salary)
        self.tool = tool

    def design(self):
        print(f"{self.name} is designing")

class Manager(Employee):
    def __init__(self, name, age, salary, teamSize):
        super().__init__(name, age, salary)
        self.teamSize = teamSize

    def lead(self):
        print(f"{self.name} is leading")

w = Developer("oshein", 26, 10000, "Bisaya")

print(w.language)
w.code()
w.work()
# Out:
# Bisaya
# oshein is coding *taktaktaktaktak*
# oshein is working

# %%
class Animal:
    def __init__(self, age, gender, weight):
        self.age = age
        self.gender = gender
        self.__weight = weight

    def eat(self, food):
        print(f"animal is eating {food}")

    def sleep(self):
        print(f"animal is sleeping")

    def makeSound(self):
        print("animal is making sound")

class Dog(Animal):
    def __init__(self, age, gender, weight, breed):
        super().__init__(age, gender, weight)
        self.breed = breed

    def makeSound(self):
        print("woof wof!!")

    def fetch(self):
        print("the dog fetched smth")

class Fish(Animal):
    def __init__(self, age, gender, weight, waterType):
        super().__init__(age, gender, weight)
        self.__waterType = waterType

    def swim(self):
        print("the duck is swimming")

    def dive(self):
        print("the duck is diving")

    def makeSound(self):
        print("quak quakc!!")


fih = Fish(12, "Female", "123kg", "Yes")

fih.makeSound()
# Out:
# quak quakc!!
