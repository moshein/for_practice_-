# %%
class GTNode:
    def __init__(self, data):
        self.data = data
        self.children = []

class Node:
    def __init__(self, data, node_type='gt'):
        self.data = data
        self.node_type = node_type

        if node_type == 'gt':
            self.children = []
        else:
            return ValueError("error aerror")
    
    def __repr__(self): ## what dos repr represents? is it represent too?
        return str(self.data)

class GTree:
    def __init__(self, root_data):
        self.root = Node(root_data, node_type='gt')

## root
gtree = GTree('fruits')
