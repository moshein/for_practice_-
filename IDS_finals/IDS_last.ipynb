# %% [markdown]
# <a href="https://colab.research.google.com/github/moshein/for_practice_-/blob/main/IDS_last.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install praw
# Out:
# Collecting praw
#   Downloading praw-7.8.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting prawcore<3,>=2.4 (from praw)
#   Downloading prawcore-2.4.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting update_checker>=0.18 (from praw)
#   Downloading update_checker-0.18.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: websocket-client>=0.54.0 in c:\users\monti\anaconda3\lib\site-packages (from praw) (1.8.0)
# Requirement already satisfied: requests<3.0,>=2.6.0 in c:\users\monti\anaconda3\lib\site-packages (from prawcore<3,>=2.4->praw) (2.32.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\monti\anaconda3\lib\site-packages (from requests<3.0,>=2.6.0->prawcore<3,>=2.4->praw) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\monti\anaconda3\lib\site-packages (from requests<3.0,>=2.6.0->prawcore<3,>=2.4->praw) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\monti\anaconda3\lib\site-packages (from requests<3.0,>=2.6.0->prawcore<3,>=2.4->praw) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\monti\anaconda3\lib\site-packages (from requests<3.0,>=2.6.0->prawcore<3,>=2.4->praw) (2025.10.5)
# Downloading praw-7.8.1-py3-none-any.whl (189 kB)
#    ---------------------------------------- 0.0/189.3 kB ? eta -:--:--
#    ---- ---------------------------------- 20.5/189.3 kB 682.7 kB/s eta 0:00:01
#    ------------ -------------------------- 61.4/189.3 kB 825.8 kB/s eta 0:00:01
#    ---------------------------------------- 189.3/189.3 kB 1.9 MB/s eta 0:00:00
# Downloading prawcore-2.4.0-py3-none-any.whl (17 kB)
# Downloading update_checker-0.18.0-py3-none-any.whl (7.0 kB)
# Installing collected packages: update_checker, prawcore, praw
# Successfully installed praw-7.8.1 prawcore-2.4.0 update_checker-0.18.0
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\anaconda_anon_usage-0.4.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\anaconda_client-1.12.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\anaconda_cloud_auth-0.5.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\certifi-2024.6.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\conda-24.5.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\conda_token-0.5.0+1.g2209e04.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\jupyterlab_server-2.25.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\pydantic-2.5.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\pydantic_core-2.14.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\anaconda_anon_usage-0.4.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\anaconda_client-1.12.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\anaconda_cloud_auth-0.5.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\certifi-2024.6.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\conda-24.5.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\conda_token-0.5.0+1.g2209e04.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\jupyterlab_server-2.25.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\pydantic-2.5.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\pydantic_core-2.14.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\typing_extensions-4.11.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\anaconda_anon_usage-0.4.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\anaconda_client-1.12.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\anaconda_cloud_auth-0.5.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\certifi-2024.6.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\conda-24.5.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\conda_token-0.5.0+1.g2209e04.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\jupyterlab_server-2.25.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\pydantic-2.5.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\pydantic_core-2.14.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\typing_extensions-4.11.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\anaconda_anon_usage-0.4.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\anaconda_client-1.12.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\anaconda_cloud_auth-0.5.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\certifi-2024.6.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\conda-24.5.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\conda_token-0.5.0+1.g2209e04.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\jupyterlab_server-2.25.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\anaconda_anon_usage-0.4.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\anaconda_client-1.12.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\anaconda_cloud_auth-0.5.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\certifi-2024.6.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\conda-24.5.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\conda_token-0.5.0+1.g2209e04.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\jupyterlab_server-2.25.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\anaconda_anon_usage-0.4.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\anaconda_client-1.12.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\anaconda_cloud_auth-0.5.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\certifi-2024.6.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\conda-24.5.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\conda_token-0.5.0+1.g2209e04.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\jupyterlab_server-2.25.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\pydantic-2.5.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\pydantic_core-2.14.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\typing_extensions-4.11.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\anaconda_anon_usage-0.4.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\anaconda_client-1.12.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\anaconda_cloud_auth-0.5.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\certifi-2024.6.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\conda-24.5.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\conda_token-0.5.0+1.g2209e04.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\jupyterlab_server-2.25.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\pydantic-2.5.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\pydantic_core-2.14.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\anaconda_anon_usage-0.4.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\anaconda_client-1.12.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\anaconda_cloud_auth-0.5.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\certifi-2024.6.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\conda-24.5.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\conda_token-0.5.0+1.g2209e04.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\jupyterlab_server-2.25.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\anaconda_anon_usage-0.4.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\anaconda_client-1.12.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\anaconda_cloud_auth-0.5.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\certifi-2024.6.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\conda-24.5.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\conda_token-0.5.0+1.g2209e04.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\monti\anaconda3\Lib\site-packages\jupyterlab_server-2.25.1.dist-info due to invalid metadata entry 'name'

# %%
import pandas as pd
import numpy as np

import praw
import requests
from requests.exceptions import ConnectionError

from tqdm.notebook import tqdm
tqdm.pandas()

from IPython.display import Markdown
from dotenv import load_dotenv
import os

import warnings
warnings.filterwarnings('ignore')

# %%
# import requests
# from IPython.display import display, Markdown

# try:
#     url = 'https://reddit.com'

#     with requests.Session() as session:
#         connection = session.get(url)

#         if connection.status_code not in [200, 202]:
#             display(
#                 Markdown(
#                     f'<b>Unexpected status code</b>: '
#                     f'{connection.status_code} {connection.reason}'
#                 )
#             )
#         else:
#             display(
#                 Markdown(
#                     f'<b>Success</b>: '
#                     f'<u><i>{connection.status_code} {connection.reason}</i></u>'
#                 )
#             )

# except requests.exceptions.ConnectionError as e:
#     display(Markdown(f'<b>Connection failed</b>: {e}'))

### output: Unexpected status code: 403 Blocked
# Out:
# <b>Unexpected status code</b>: 403 Blocked

# %%
# import requests
# from IPython.display import display, Markdown

# try:
#     url = 'https://reddit.com'

#     headers = {
#         "User-Agent": "Mozilla/5.0"
#     }

#     with requests.Session() as session:
#         connection = session.get(url, headers=headers)

#         if connection.ok:
#             display(
#                 Markdown(
#                     f'<b>Success</b>: '
#                     f'<u><i>{connection.status_code} {connection.reason}</i></u>'
#                 )
#             )
#         else:
#             display(
#                 Markdown(
#                     f'<b>Unexpected status code</b>: '
#                     f'{connection.status_code} {connection.reason}'
#                 )
#             )

# except requests.exceptions.ConnectionError as e:
#     display(Markdown(f'<b>Connection failed</b>: {e}'))
# Out:
# <b>Unexpected status code</b>: 403 Blocked

# %%
"""
    This is to test if we can access reddit.com prior to getting our data
    using requests. 
"""

try:
    session = requests.Session()
    url = 'https://reddit.com'
    connection = session.get(url)
    if connection.status_code != 202 and connection.status_code != 200:
        display(Markdown(f"<b>Unexpected status code</b>: {connection.status_code} {connection.reason}"))
    else:
        display(Markdown(f"<b>Success</b>: <u><i>{connection.status_code} {connection.reason}</u></i>"))
except ConnectionError as e:
    display(Markdown(f"<b>Connection failed</b>: {e}"))
# Out:
# <b>Success</b>: <u><i>200 OK</u></i>

# %%
load_dotenv()

client_id = os.getenv('CLIENT_ID')
client_secret = os.getenv('SECRET_KEY')
user_agent = os.getenv('USER_AGENT')

# %%
try:
    reddit = praw.Reddit(client_id= client_id,
                         client_secret= client_secret,
                         user_agent= user_agent)
except Exception as e:
    print(f'Error using PRAW - {e}')
