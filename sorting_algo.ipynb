# %% [markdown]
# <a href="https://colab.research.google.com/github/moshein/for_practice_-/blob/main/sorting_algo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class QueueL:
  def __init__(self):
    self.queue = []

  def enqueue(self, data):
    # if self.rear is None:
    #   self.front = self.rear = data
    ## no need na diay kay list man rawrwrwrwarwarwr

    self.queue.append(data)

  def dequeue(self):
    # self.queue.pop(0)
    # return
    ### ga work gyapon sya peroo safer if i-put gyud sya sa last

    return self.queue.pop(0)

  def search_lin(self, key):
    for i in range(len(self.queue)):
      if self.queue[i] == key:
        return print(f"{key} is in [{i}] index")
    return -1

  def display(self):
    return self.queue

# %%
q = QueueL()

q.enqueue(1)
q.enqueue(3)
q.enqueue(2)
q.enqueue(7)
q.enqueue(4)
q.enqueue(9)
q.display()
# Out:
# [1, 3, 2, 7, 4, 9]

# %%
q.dequeue()
q.display()
# Out:
# [3, 2, 7, 4, 9]

# %%
q.search_lin(7)
# Out:
# 7 is in [2] index

# %%
### rawrawrawrawrawrwr dili pa diay mag make ug list daan rawrawrawrawrwarwarwarwr

# nums = [10,50,30,70,80,60,20,90,40]
