# %% [markdown]
# <a href="https://colab.research.google.com/github/moshein/for_practice_-/blob/main/dictionary_exercise_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practice: Trial #1 </br>
#
# ## Takeaways: </br>
#
#
# *   need to learn new + basic stuff at the same time
# *   must not rely only on one thing or another

# %%
## testing if this code will also appear in github
## nope it didnt appear
## pero it appeared after clicking save

# %%
transactions = ["apple", "banana", "apple", "orange", "banana", "apple"]

fin_trans = {}

for i in transactions:
  if i not in fin_trans:
    fin_trans[i] = 1
  else:
    fin_trans[i] += 1

print(fin_trans)
# Out:
# {'apple': 3, 'banana': 2, 'orange': 1}

# %%
data = [
    {"item": "apple", "price": 10},
    {"item": "banana", "price": 5},
    {"item": "apple", "price": 15}
]

sum_items = {}

# for i in data:
#   if data[i]["item"] not in sum_items:
#     sum_items[data[i]["item"]] = data[i]["price"]
#   else:
#     sum_items[data[i]["item"]] += data[i]["price"]


for i in data:
  if i["item"] not in sum_items:
    sum_items[i["item"]] = i["price"]
  else:
    sum_items[i["item"]] += i["price"]

print(sum_items)
# Out:
# {'apple': 25, 'banana': 5}

# %%
scores = {"math": 90, "science": 75, "english": 85}

up_80 = {}

for i in scores:
  if scores[i] >= 80:
    up_80[i] = scores[i]

print(up_80)
# Out:
# {'math': 90, 'english': 85}

# %%
d = {"a": 1, "b": 2, "c": 1, "d": 3}

duplicates_d = []

for i in d:
  if i != len(d): # i have a feeling mag error ni
    for i+1 in d: # i think unnecessary ni
      if d[i] == d[i+1]:
        duplicates_d.append(d[i+1])

print(duplicates_d)

### uhm... mas maka save tag time if ato i-learn first every methods ni dict
### well, although, nice ma-learn ang logic, we're no longer in a cave naman
### it's like... we kinda need to learn to be more efficient
### we can learn dict methods, but at the same time, learn logic too
### we also need to learn logic PUD ha


### we need to LEARN NEW + BASIC THINGS


### kay it's more efficient


### BUT we MUST NOT RELY SOLELY on NEW THINGS
### we NEED TO LEARN THE BASICS too

### we also MUST NOT RELY SOLELY on BASIC THINGS
### we also NEED TO LEARN THE NEW STUFF too
# Out:
#   File "/tmp/ipykernel_510/2696511924.py", line 7
#     for i+1 in d: # i think unnecessary ni
#         ^
# SyntaxError: cannot assign to expression

# %%
hi = "mikumikumii"

print(len(hi))
# Out:
# 11

# %%
word = "banana"

list_letters = {}

for i in word:
  if i not in list_letters.keys():
    list_letters = list_letters + dict(i, 1)

print(list_letters)

### gurl... dili man diay ta kabalo unsaon pag make ug dictionary...
### gurl... mura gyud diay syag pandas ba...
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_180/2747560512.py in <cell line: 0>()
#       5 for i in word:
#       6   if i not in list_letters.keys():
# ----> 7     list_letters = list_letters + dict(i, 1)
#       8
#       9 print(list_letters)
#
# TypeError: dict expected at most 1 argument, got 2

# %%
word = "banana"

list_letters = {}

for i in word:
  if i not in list_letters.keys():
    list_letters[i] = 1
  else:
    list_letters[i] += 1

print(list_letters)
# Out:
# {'b': 1, 'a': 3, 'n': 2}

# %%
phrase = "God is good God is faithful"

phrase_list = []
ini_list = ""
fin_list = {}

for i in phrase:
  ## ini_list = ""
  ## this code resets man everytime mag run sya for each letter
  if i != " ":
    ini_list += i
  else:
    phrase_list.append(ini_list)
    ini_list = "" ## added this line of code to reset AFTER saving the word
# print(phrase_list)


###############################################

#### still incorrect diay btw kaaaaay
#### ang goal is to count how many times each word appears man gud

####### ANYWAAYY NA FIX NA HUAHUAHUAHUAUA with the help of our AI fren, solin

###############################################


phrase_list.append(ini_list)
# print(phrase_list)


for i in phrase_list:
  if i not in fin_list:
    fin_list[i] = 1
  else:
    fin_list[i] += 1

print(fin_list)
# Out:
# {'God': 2, 'is': 2, 'good': 1, 'faithful': 1}

# %%
scores = {
    "math": 90,
    "science": 95,
    "english": 88
    }

base_score = scores["math"]

for i in scores:
  if scores[i] > base_score:
    base_score = scores[i]

print(base_score)
# Out:
# 95

# %%
d1 = {"a": 1, "b": 2}
d2 = {"c": 3, "d": 4}

d1.update(d2)

print(d1)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %% [markdown]
# # Practice: Trial 2 </br>
#
# ## Takeaways: </br>
#
#
# 1.   List item
# 2.   List item

# %% [markdown]
# ![655080780_4439161829686955_7366611828923531218_n.png](data:image/png;base64,...)

# %%
### goal: using get(), safely get a value (no error if key doesn't exist)

d = {"apple": 10, "banana": 5}

print(d.get("orange", 0))
# Out:
# 0

# %%
word = "banana"

# num_letters = {}

# for i in word:
#   if i not in num_letters:
#     num_letters.get(i, 1)
#   else:
#     num_letters[i] += 1

# print(num_letters)

###########################################
###########################################
##### the program above didnt work cuuz
##### get() DOESNT MODIFY the dictionary
###########################################
###########################################

num_letters = {}

for i in word:
  num_letters[i] = num_letters.get(i, 0) + 1

print(num_letters)

#### nagpa help nalang ko kay chatgpt ani kay galisod ko T^T
#### actually ang na happen ani kay nag ask lang ko why wala nag work ang previous
#### kasooo si chatgpt nag make ug 2 ways to fix it
#### that's the second way of fixing it
# Out:
# {'b': 1, 'a': 3, 'n': 2}

# %%
print(num_letters.keys())
print(num_letters.values())
print(num_letters.items())
# Out:
# dict_keys(['b', 'a', 'n'])
# dict_values([1, 3, 2])
# dict_items([('b', 1), ('a', 3), ('n', 2)])

# %%
d.update({"c": 3})

print(d)
# Out:
# {'apple': 10, 'banana': 5, 'c': 3}

# %%
d1 = {"a": 1}
d2 = {"b": 2}

d1.update(d2)

print(d1)
# Out:
# {'a': 1, 'b': 2}

# %%
# 1. merge

d1 = {"a": 1, "b": 2}
d2 = {"b": 3, "c": 4}

d1.update(d2)
print(d1)

# 2. if key exists, increase value instead of replacing

for i in d1:
  if i in d2.keys():
    d1[i] += d2[i] # naay mali ani............ hMMm

print(d1)
# Out:
# {'a': 1, 'b': 3, 'c': 4}
# {'a': 1, 'b': 6, 'c': 8}

# %%
print('sample lungz as im trying to save my work from VS Code to GitHub')
# Out:
# sample lungz as im trying to save my work from VS Code to GitHub

# %%
print("another sample kay dugay sya kanina rawrawr")
# Out:
# another sample kay dugay sya kanina rawrawr

# %%
print("another sample for pull cuz i juz wanna see")
# Out:
# another sample for pull cuz i juz wanna see
