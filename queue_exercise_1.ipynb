# %% [markdown]
# <a href="https://colab.research.google.com/github/moshein/for_practice_-/blob/main/queue_exercise_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### please try with class Node daw beehh kay walay class Node here
### no need na diay mag use ug class Node becuzz
### we're using list and not linkedList rawrawr
### so yup

# %%
class QueueList:
  def __init__(self, max_size):
    self.queue_L = []
    self.max = max_size

  def enqueue(self, data):
    # max_size += 1 ### this one is removed but why???
    ################### sabaw man ka gurl
    ################### kay dili man dapat niya na i-count TT^TT
    ################### dapat si user mismo mag input pilay maximum
    ################### rawrawrwarawrwrawr
    return self.queue_L.append(data)

  def dequeue(self):
    # max_size -= 1 ### this one is removed but why???
    ################### sabaw man ka gurl
    ################### kay dili man dapat niya na i-count TT^TT
    ################### dapat si user mismo mag input pilay maximum
    ################### rawrawrwarawrwrawr
    return self.queue_L.pop(0)

  def peek(self):
    return print(self.queue_L[0])

  def size(self):
    return print(len(self.queue_L))

  def is_empty(self):
    # if len(self.queue_L) == 0: ### can be written in one line
    #   return True
    # else:
    #   return False
    return len(self.queue_L) == 0

  def is_full(self):
    # if len(self.queue_L) == max_size: ### can be written in one line
    #   return True
    # else:
    #   return False
    return len(self.queue_L) == self.max

# %% [markdown]
# ### Queue using List

# %%
class QueueList:
  def __init__(self, max_size):
    self.queue_L = []
    self.max = max_size

  def enqueue(self, data):
    return self.queue_L.append(data)

  def dequeue(self):
    return self.queue_L.pop(0)

  def peek(self):
    return print(self.queue_L[0])

  def size(self):
    return print(len(self.queue_L))

  def is_empty(self):
    return len(self.queue_L) == 0

  def is_full(self):
    return len(self.queue_L) == self.max

# %%
q = QueueList(3)
q.enqueue("rawrawr")
q.enqueue("miku")
q.enqueue("hatsune")
print(q.queue_L)
print("")
# Out:
# ['rawrawr', 'miku', 'hatsune']

# %%
q.dequeue()
# Out:
# 'rawrawr'

# %%
q.peek()
# Out:
# miku

# %%
q.size()
# Out:
# 2

# %%
q.is_empty()
# Out:
# False

# %%
q.is_full()
# Out:
# False

# %%
## our self.max here is broken  whyy??
## kay cge daw ka-replace si max sa 0

class QueueList:
  def __init__(self, max):
    self.queue_L = []
    self.max = 0 ## kay cge daw ka-replace si max sa 0

  def enqueue(self, data):
    self.max += 1
    return self.queue_L.append(data)

  def dequeue(self):
    self.max -= 1
    return self.queue_L.remove(q.queue_L[0]) ### this one is not for FIFO dequeue daw askdfsjfah

  def peek(self):
    return print(self.queue_L[0])

  def size(self):
    return print(len(self.queue_L))

  def is_empty(self):
    if len(self.queue_L) == 0:
      return True
    else:
      return False

  def is_full(self):
    if len(self.queue_L) == max:
      return True
    else:
      return False

q = QueueList(2)
q.enqueue("rawrawr")
q.enqueue("miku")
q.enqueue("hatsune")
print(q.queue_L)
print("")

q.dequeue()
print(q.queue_L)

q.peek()

q.size()

# q.is_empty()

q.is_full()
# Out:
# ['rawrawr', 'miku', 'hatsune']
#
# ['miku', 'hatsune']
# miku
# 2
# False

# %%
### may error rawrawrawr

class QueueList:
  def __init__(self, data):
    self.data = data

  def enqueue(self, data):
    return self.append(data)

q = QueueList()

q.enqueue("rawrawr")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_12229/404048020.py in <cell line: 0>()
#       6     return self.append(data)
#       7
# ----> 8 q = QueueList()
#       9
#      10 q.enqueue("rawrawr")
#
# TypeError: QueueList.__init__() missing 1 required positional argument: 'data'

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.next = None

class QueueList:
  def __init__(self):
    self.queue_L = []

  def enqueue(self, data):
    self.queue_L.append(data)

# %%
q = QueueList()

q.enqueue("rawr")

## this returns to None man daw

# %%
#### this is wrong rawrawrawr

class Node:
  def __init__(self, data):
    self.data = data
    self.next = None

class QueueList:
  def __init__(self, queue_L):
    self.rear = None
    self.queue_L = queue

  def enqueue(self, data):
    return self.queue.append(data)

# %%
q = QueueList()

q.enqueue("rawr")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_12229/3268565199.py in <cell line: 0>()
# ----> 1 q = QueueList()
#       2
#       3 q.enqueue("rawr")
#
# TypeError: QueueList.__init__() missing 1 required positional argument: 'queue_L'
