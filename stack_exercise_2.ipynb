# %% [markdown]
# # Stack Using List

# %% [markdown]
# # Stack Using Linked List

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class StackLL:
    def __init__(self):
        self.top = None

    def push(self, data):
        new_node = Node(data)
        new_node.next = self.top
        self.top = new_node

    def display(self):
        temp = self.top

        while temp:
            print(temp.data, end="  ->  ")
            temp = temp.next

        print("None")

# %%
s = StackLL()

s.push(1)
s.push(2)
s.push(3)

s.display()
# Out:
# 3  ->  2  ->  1  ->  None

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class StackLL:
    def __init__(self):
        self.top = None

    def push(self, data):
        new_node = Node(data)
        new_node.next = self.top
        self.top = new_node

        ### [.next] doesnt care about left or right
        ### it just means that this node points to another node and that's it

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.next = None

class StackLL:
  def __init__(self):
    self.top = None

  def push(self, data):
    new_node = Node(data)

    new_node.next = self.top

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.next = None

class StackLL:
  def __init__(self):
    self.top = None

  def push(self, data):
    new_node = Node(data)
    new_node.next = self.top ### we point the new node to the top
    self.top = new_node ### then here we make the top point to the new node

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.next = None

class StackLL:
  def __init__(self):
    self.top = None

  def push(self, data):
    new_node = Node(data)
    new_node.next = self.top
    self.top = new_node

  def pop(self):
    popped_value = self.top
    self.top = self.top.next
    return popped_value.data

  def peek(self):
    return self.top.data

  def is_empty(self):
    return self.top is None
  
  def display(self):
    temp = self.top

    while temp:
      print(temp.data, end="  ->  ")
      temp = temp.next
    print("none")

# %%
s = StackLL()

s.push(1)
s.push(2)
s.push(3)

s.display()
# Out:
# 3  ->  2  ->  1  ->  none

# %% [markdown]
# # Queue

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.next = None

class QueueLL:
  def __init__(self):
    self.front = None
    self.rear = None

  def enqueue(self, data):
    new_node = Node(data)

    ### well... i experimented these lines of code below..
    # new_node.next = self.front
    # self.front = new_node

    ### assumption: queue's order is the same as stack's order
    ### output: code ran as expected
    ### is assumption correct? WRONG
    ### CORRECTION: queue's order must be DIFFERENT from stack's 

    ### i assumed that the order of queue should also be the same as stack
    ### where the first one should be the last...
    ### well our code ran as expected
    ### it's just that our assumption is wrong

  def dequeue(self):
    pass

  def display(self):
    temp = self.front

    while temp:
      print(temp.data, end="  ->  ")
      temp = temp.next
    print("none")

# %%
q = QueueLL()

q.enqueue(1)
q.enqueue(2)
q.enqueue(3)

q.display()
# Out:
# 3  ->  2  ->  1  ->  none

# %% [markdown]
# # Review for linked list, stack, & queue

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None
    
    def append(self, data):
        new_node = Node(data)

        if not self.head:
            self.head = new_node
            return

        temp = self.head
        while temp.next:
            temp = temp.next
        
        temp.next = new_node

    def prepend(self, data):
        new_node = Node(data)
        new_node.next = self.head
        self.head = new_node

    def insert(self, idx, value):
        new_node = Node(value)

        if idx == 0:
            new_node.next = self.head
            self.head = new_node
            return
        
        temp = self.head
        for _ in range(idx - 1):
            temp = temp.next
        
        new_node.next = temp.next
        temp.next = new_node

    
    def pop(self):
        temp = self.head

        while temp.next.next:
            temp = temp.next
        
        popped_value = temp.next
        temp.next = None
        return popped_value.data
    
    def remove(self, key):
        temp = self.head

        if temp.data == key:
            self.head = temp.next
            return
        
        while temp.next:
            if temp.next.data == key:
                #temp.next == temp.next.next ## this line is WRONG
                ## it returns a boolean value

                temp.next = temp.next.next
                return
            temp = temp.next

    def sort(self):
        temp1 = self.head

        while temp1:
            temp2 = temp1.next

            while temp2:
                if temp1.data > temp2.data:
                    temp1.data, temp2.data = temp2.data, temp1.data
                temp2 = temp2.next
            temp1 = temp1.next

    def search(self,key):
        temp = self.head
        position = 0 

        while temp:
            if temp.data == key:
                print(f"Found [{key}] at position[{position}].")
                return True
                
            temp = temp.next
            position += 1
        
        print("Value not found :<")
        return False

    def length(self):
        count = 0
        temp = self.head

        while temp:
            count += 1
            temp = temp.next
        return count

    
    def display(self):
        temp = self.head

        while temp:
            print(temp.data, end="  ->  ")
            temp = temp.next

        print("None")

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
ll = LinkedList()

ll.append(1)
ll.append(2)
ll.append(3)
ll.append(6)
ll.append(2)
ll.append(5)
ll.append(4)
ll.display()

ll.pop()

ll.sort()
ll.display()

ll.length()

ll.insert(1, 9)
ll.display()
# Out:
# 1  ->  2  ->  3  ->  6  ->  2  ->  5  ->  4  ->  None
# 1  ->  2  ->  2  ->  3  ->  5  ->  6  ->  None
# 1  ->  9  ->  2  ->  2  ->  3  ->  5  ->  6  ->  None

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class StackLL:
    def __init__(self):
        self.top = None
    
    def push(self, data):
        new_node = Node(data)
        new_node.next = self.top
        self.top = new_node
    
    def pop(self):
        temp = self.top
        popped_value = temp.data
        self.top = temp.next

        return popped_value
    
    def peek(self):
        return self.top.data
    
    def display(self):
        temp = self.top

        while temp:
            print(temp.data, end="  ->  ")
            temp = temp.next
        print("none")

# %%
s = StackLL()

s.push(1)
s.push(3)
s.push(2)

s.pop()

s.display()

s.peek()
# Out:
# 3  ->  1  ->  none
# 3

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class Queue:
    def __init__(self):
        self.front = None
        self.rear = None
    
    def enqueue(self, data):
        new_node = Node(data)

        if self.rear is None:
            self.front = self.rear = new_node
            return
        
        self.rear.next = new_node
        self.rear = new_node
    
    def dequeue(self):
        removed_value = self.front
        self.front = self.front.next

        if self.front is None:
            self.rear = None
        
        return removed_value
    
    def peek(self):
        return self.front.data
