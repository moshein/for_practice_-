# %% [markdown]
# <a href="https://colab.research.google.com/github/moshein/for_practice_-/blob/main/linked_list_exercise_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prob 1 </br>
# ## Trial 1

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.next = None

class LinkedList:
  def __init__(self):
    self.head = None

  def append(self,data):
    mikUdayOu = Node(data)

    if not self.head:
      self.head = mikUdayOu

    temp = self.head
    while temp.next:
      temp = temp.next

    temp.next = mikUdayOu

  def display(self):
    temp = self.head

    while temp:
      print(temp.data, end="  ->  ")
      temp = temp.next

# %%
n1 = Node('apple')
n2 = Node('Miku')
n3 = Node('Hatsune')
n4 = Node('Mikudayo')

# %%
n1.next = n2
n2.next = n3
n3.next = n4

# %%
ll = LinkedList()

ll.append('Jhun')
ll.append('Brian')
ll.append('Matic')
ll.append('Andam')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_373/2173662974.py in <cell line: 0>()
#       2
#       3 ll.append('Jhun')
# ----> 4 ll.append('Brian')
#       5 ll.append('Matic')
#       6 ll.append('Andam')
#
# /tmp/ipykernel_373/3020326633.py in append(self, data)
#      15
#      16     temp = self.head
# ---> 17     while temp.next:
#      18       temp = temp.next
#      19
#
# KeyboardInterrupt:

# %% [markdown]
# # Error documentation </br>
#
# ![655757467_1637207094092458_2886944053196062499_n.png](data:image/png;base64,...)
#
# </br>
# i think kulang sya... not sure

# %% [markdown]
# ## Trial 2

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.next = None

  def __repr__(self):
    return str(self.data)

class LinkedList:
  def __init__(self):
    self.head = None

  def append(self,data):
    mikUdayOu = Node(data)
    if not self.head:
      self.head = mikUdayOu
      return #OMAYGHAD WALA DIAY TA NAKA INPUT UG RETURN
      # didnt know we can place "return" mid code

    temp = self.head
    while temp.next:
      temp = temp.next

    temp.next = mikUdayOu

  def display(self):
    temp = self.head

    while temp:
      print(temp.data, end="  ->  ")
      temp = temp.next

# %%
ll = LinkedList()

ll.append('Jhun')
ll.append('Brian')
ll.append('Matic')
ll.append('Andam')

# %%
ll.display()
# Out:
# Jhun  ->  Brian  ->  Matic  ->  Andam  ->

# %% [markdown]
# ---

# %% [markdown]
# ![661282089_1696096264896543_7552191173946195655_n.png](data:image/png;base64,...)

# %% [markdown]
# # Prob 2
# ## Trial 1

# %%
class LinkedList2:
  def __init__(self):
    self.head = None

  def append(self, data):
    new_node = Node(data)
    if not self.head:
      self.head = new_node
      return

    mikumikumi = self.head
    while mikumikumi.next:
      mikumikumi = mikumikumi.next

    mikumikumi.next = new_node

  def display(self):
    temp = self.head
    while temp:
      print(temp.data, end="  miku-->  ")
      temp = temp.next
    print('None')

# %%
mikuDayOiu = LinkedList2()

mikuDayOiu.append('MOCHI')
mikuDayOiu.append('MOCHII')

# %%
mikuDayOiu.display()
# Out:
# MOCHI  miku-->  MOCHII  miku-->  None

# %% [markdown]
# ## Trial 2

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.next = None

class LinkedList3:
  def __init__(self):
    self.head = None

  def display(self):
    temp = self.head
    while temp:
      print(temp.data, end="  ->  ")
      temp = temp.next
    print('None')

  def append(self, data):
    newNode = Node(data)
    if not self.head:
      self.head = newNode
      return

    temp = self.head
    while temp.next:
      temp = temp.next

    temp.next = newNode

  def remove(self, key):
    temp = self.head

    if temp.data == key:
      self.head = temp.next
      return

    while temp.next:
      if temp.next.data == key:
        temp.next = temp.next.next
        return
      temp = temp.next

# %%
mikuLL = LinkedList3()

mikuLL.append('Miku')
mikuLL.append('hatsune')
mikuLL.append('luyahan')
mikuLL.append('entwuh')

# %%
mikuLL.display()
# Out:
# Miku  ->  hatsune  ->  luyahan  ->  entwuh  ->  None

# %% [markdown]
# ## Trial 3
# </br>
# tryin to explore by intentionally breaking this program

# %% [markdown]
# ### Breaking the display() method

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.next = None

class LinkedList3:
  def __init__(self):
    self.head = None

  def display(self):
    temp = self.head
    while temp:
      print(temp.data, end="  ->  ")
      # temp = temp.next ## breaking the display() method by deleting this line of code
    print('None')

  def append(self, data):
    newNode = Node(data)
    if not self.head:
      self.head = newNode
      return

    temp = self.head
    while temp.next:
      temp = temp.next

    temp.next = newNode

  def remove(self, key):
    temp = self.head

    if temp.data == key:
      self.head = temp.next
      return

    while temp.next:
      if temp.next.data == key:
        temp.next = temp.next.next
        return
      temp = temp.next

# %%
### uhm so...
### gi-remove nako tung test for this program
### kaay nag lag ako chrome tab TT^TT
### na-break gyud ang program TT^TT

# %% [markdown]
# ### Breaking the append() method

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.next = None

class LinkedList3:
  def __init__(self):
    self.head = None

  def display(self):
    temp = self.head
    while temp:
      print(temp.data, end="  ->  ")
      temp = temp.next
    print('None')

  def append(self, data):
    newNode = Node(data)
    if not self.head:
      self.head = newNode
      return

    temp = self.head
    while temp: ## deleted temp.next
      temp = temp.next

    # temp.next = newNode ## deleted this line of code too para makita gyud nato

  def remove(self, key):
    temp = self.head

    if temp.data == key:
      self.head = temp.next
      return

    while temp.next:
      if temp.next.data == key:
        temp.next = temp.next.next
        return
      temp = temp.next

# %%
### assumption: mag loop ra sya sa head node

# %%
mikuLL = LinkedList3()

mikuLL.append('Miku')
mikuLL.append('hatsune')
mikuLL.append('luyahan')
mikuLL.append('entwuh')

mikuLL.display()
# Out:
# Miku  ->  None

# %%
### result: correct ato assumption
### wala gyud sya ni-proceed

# %% [markdown]
# ### Removing the empty list
# *wala ko nag expect na empty list diay ni na part rawrawrawr*

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.next = None

class LinkedList3:
  def __init__(self):
    self.head = None

  def display(self):
    temp = self.head
    while temp:
      print(temp.data, end="  ->  ")
      temp = temp.next
    print('None')

  def append(self, data):
    newNode = Node(data)
    # if not self.head:
    #   self.head = newNode
    #   return

    temp = self.head
    while temp.next:
      temp = temp.next

    temp.next = newNode

  def remove(self, key):
    temp = self.head

    if temp.data == key:
      self.head = temp.next
      return

    while temp.next:
      if temp.next.data == key:
        temp.next = temp.next.next
        return
      temp = temp.next

# %%
### chatgpt said that there must be an error but there's no error man
### si Miku lang nigawas

# %%
mikuLL = LinkedList3()

mikuLL.append('Miku')
mikuLL.append('hatsune')
mikuLL.append('luyahan')
mikuLL.append('entwuh')

mikuLL.display()
# Out:
# Miku  ->  None

# %% [markdown]
# ### Making a subtle bug

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.next = None

class LinkedList3:
  def __init__(self):
    self.head = None

  def display(self):
    temp = self.head
    while temp:
      print(temp.data, end="  ->  ")
      temp = temp.next
    print('None')

  def append(self, data):
    newNode = Node(data)
    if not self.head:
      self.head = newNode
      return

    temp = self.head
    while temp.next:
      temp = temp.next

    temp.next = newNode

  def remove(self, key):
    temp = self.head

    if temp.data == key:
      self.head = temp.next
      return

    while temp.next:
      if temp.data == key: ## removed temp.next.data
        temp.next = temp.next.next
        return
      temp = temp.next

# %%
mikuLL = LinkedList3()

mikuLL.append('Miku')
mikuLL.append('hatsune')
mikuLL.append('luyahan')
mikuLL.append('entwuh')

mikuLL.remove('entwuh')

mikuLL.display()
# Out:
# Miku  ->  hatsune  ->  luyahan  ->  entwuh  ->  None
