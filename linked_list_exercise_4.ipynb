# %%
class miku_children:
    def __init__(self, name):
        self.name = str(name)
        self.greet = "hi im " + name

# %%
mikus = miku_children()

mikus.name("meku")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 mikus = miku_children()
#       3 mikus.name("meku")
#
# TypeError: miku_children.__init__() missing 1 required positional argument: 'name'

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
