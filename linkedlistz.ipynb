# %% [markdown]
# <a href="https://colab.research.google.com/github/moshein/for_practice_-/blob/main/linkedlistz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(f'google colab is actingnfunny rawrawr')

class Node:
  def __init__(miku, data):
    miku.data = data

ll = Node("mikuwaaa")

print(ll.data)
# Out:
# google colab is actingnfunny rawrawr
# mikuwaaa
