# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


class LinkedList:
    def __init__(self):
        self.head = None

    def append(self, data):
        new_node = Node(data)

        if not self.head:
            self.head = new_node
            return

        temp = self.head

        while temp.next:
            temp = temp.next

        temp.next = new_node

    def remove(self, key):
        temp = self.head

        if temp.data == key:
            temp.data = temp.next
            return

        while temp.next:
            if temp.next.data == key:
                temp.next = temp.next.next
                return
            temp = temp.next


    def display(self):
        temp = self.head

        while temp:
            print(temp.data, end='  ->  ')
            temp = temp.next
        print("None")

# %%
ll = LinkedList()

ll.append(1)
ll.append(2)
ll.append(3)
ll.display()
# Out:
# 1  ->  2  ->  3  ->  None

# %%
ll.remove(1)
ll.display()
# Out:
# <__main__.Node object at 0x0000019F6567AF90>  ->  2  ->  3  ->  None

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def append(self, data):
        new_node = Node(data)

        if not self.head:
            self.head = new_node
            return

        temp = self.head

        while temp.next:
            temp = temp.next

        temp.next = new_node

    def remove(self, key):
        temp = self.head

        if temp.data == key: 
            self.head == temp.next
            return

        while temp.next:
            if temp.next.data == key:
                temp.next == temp.next.next
                return
            temp = temp.next

    def sort(self):
        temp1 = self.head

        while temp1:
            temp2 = temp1.next

            while temp2:
                if temp1.data > temp2.data:
                    temp1.data, temp2.data = temp2.data, temp1.data
                temp2 = temp2.next
            temp1 = temp1.next

    def search(self, key):
        temp = self.head
        position = 0

        while temp:
            if temp.data == key:
                print(f"Found {key} at position {position}")
                return True
            temp = temp.next
            position += 1

        print("Value not found")
        return False

    def length(self):
        temp = self.head
        count = 0

        while temp:
            count += 1
            temp = temp.next
        return count

    def display(self):
        temp = self.head

        while temp:
            print(temp.data, end='  ->  ')
            temp = temp.next
        print('None')

# %%
ll = LinkedList()

ll.append(1)
ll.append(3)
ll.append(2)
ll.append(7)

ll.display()

ll.sort()
ll.display()

ll.search(3)

ll.length()

print(ll.head.data)
# Out:
# 1  ->  3  ->  2  ->  7  ->  None
# 1  ->  2  ->  3  ->  7  ->  None
# Found 3 at position 2
# 1

# %%
nums = [1,2,3,4,5,6,7]

while i in nums:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 3
#       1 nums = [1,2,3,4,5,6,7]
# ----> 3 while i in nums:
#       4     print(i)
#
# NameError: name 'i' is not defined

# %%
## si linked list kay pwede mag start anywhere as long as mag start sya sa any ends and dili mag start in between

# %%
class Node:
    def __init__(self_customized, data):
        self_customized.data = data
        self_customized.next = None

class LinkedList:
    def __init__(self):
        self.head = None
    
    def append(self, data):
        new_node = Node(data)

        if not self.head:
            self.head = new_node
            return

        temp = self.head
        while temp.next:
            temp = temp.next
        
        temp.next = new_node
    
    def display(self):
        temp = self.head

        while temp:
            print(temp.data, end="  ->  ")
            temp = temp.next
        print("None")

# %%
ll = LinkedList()

ll.append(1)
ll.append(2)
ll.append(3)
ll.append(4)

ll.display()
# Out:
# 1  ->  2  ->  3  ->  4  ->  None

# %%
class Node:
    def __init__(self, data):
        self.data = data

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
    
class LinkedList:
    def __init__(self):
        self.head = None
    
    def append(self, data):
        new_node = Node(data)

        if not self.head:
            self.head = new_node
            return

        temp = self.head

        while temp.next:
            temp = temp.next
        
        temp.next = new_node
    
    def remove(self, key):
        temp = self.head

        if temp.data == key:
            temp.data == temp.next 
            return
        
        while temp.next:
            if temp.next.data == key:
                ## temp.next.data = temp.next.next.data
                ### output: 
                ### 1  ->  2  ->  3  ->  4  ->  none
                ### 1  ->  2  ->  4  ->  4  ->  none
                
                temp.next = temp.next.next
                
                return
            
            temp = temp.next

    def sort(self):
        temp1 = self.head
        while temp1:
            temp2 = temp1.next
            while temp2:
                if temp1.data > temp2.data:
                    temp1.data, temp2.data = temp2.data, temp1.data
                temp2 = temp2.next
            temp1 = temp1.next
    
    def display(self):
        temp = self.head

        while temp:
            print(temp.data, end="  ->  ")
            ## rawr nakalimot ta mag add ug temp = temp.next
            temp = temp.next

        print("none")

# %%
ll = LinkedList()

ll.append(1)
ll.append(2)
ll.append(3)
ll.append(4)
ll.display()

ll.remove(3)
ll.display()
# Out:
# 1  ->  2  ->  3  ->  4  ->  none
# 1  ->  2  ->  4  ->  none

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.chuya = None ### i changed next to chuya cuz nag wonder ko na
                          ### why ma-access si next when in fact it's from a different class
                          ### better explanation found on pic above^^^

### i really thought na the append function makes a copy of the node containing the data
### it references or pointing it to the node containing the data diayy
### The Node object stores the data
### Variables (like head, temp) only stores the references to the Node object
                         

class LinkedList:
    def __init__(self):
        self.head = None
    
    def append(self, data):
        new_node = Node(data)

        if not self.head:
            self.head = new_node
            return
        
        temp = self.head

        while temp.chuya:
            temp = temp.chuya
        
        temp.chuya = new_node

    def display(self):
        temp = self.head

        while temp:
            print(temp.data, end="  ->  ")
            temp = temp.chuya
        print("nonee")

# %%
ll = LinkedList()

ll.append(1)
ll.append(2)
ll.append(3)
ll.append(4)
ll.display()
# Out:
# 1  ->  2  ->  3  ->  4  ->  nonee

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None
    
    def append(self, data):
        new_node = Node(data)

        if not self.head:
            self.head = new_node
            return
        
        temp = self.head

        while temp.next:
            temp = temp.next
        
        temp.next = new_node

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None
    
    def append(self, data):
        new_node = Node(data)

        if not self.head:
            self.head = new_node
            return
        
        temp = self.head

        while temp.next:
            temp = temp.next
        
        temp.next = new_node
    
    def remove(self, key):
        temp = self.head

        if temp.data == key:
            self.head == temp.next
            return
        
        while temp.next:
            if temp.next.data == key:
                temp.next == temp.next.next
                return
            temp = temp.next
    
    def sort(self):
        temp1 = self.head

        while temp1:
            temp2 = temp1.next

            while temp2:
                if temp1.data > temp2.data:
                    temp1.data, temp2.data = temp2.data, temp1.data
                temp2 = temp2.next
            temp1 = temp1.next

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
    
class LinkedList:
    def __init__(self):
        self.head = None
    
    def append(self, data):
        new_node = Node(data)

        if not self.head:
            self.head = new_node
            return
        
        temp = self.head

        while temp.next:
            temp = temp.next
        
        temp.next = new_node

    def remove(self, key):
        temp = self.head

        # if temp.data == key:
        #        temp.data == temp.next.data 
        ### ma-duplicate diay sya rawrawr
        ### sakto sakto

        if temp.data == key:
            self.head == temp.next
            return

        while temp.next:
            if temp.next.data == key:
                temp.next == temp.next.next
                return
            temp = temp.next
    
    def sort(self):
        temp1 = self.head

        while temp1:
            temp2 = temp1.next

            while temp2:
                if temp1.data > temp2.data:
                    temp1.data, temp2.data = temp2.data, temp1.data
                temp2 = temp2.next
            temp1 = temp1.next
    
    def search(self, key):
        temp = self.head
        position = 0

        while temp:
            if temp.data == key:
                print(f"Found [{key}] at position [{position}]")
                return True
            temp = temp.next
            position += 1
        
        print("Value not found")
        return False
    
    def length(self):
        temp = self.head
        count = 0

        while temp:
            count += 1
            temp = temp.next
        return count
    
    def display(self):
        temp = self.head

        while temp:
            print(temp.data, end="  ->  ")
            temp = temp.next
        print("None")

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)
# ![image-2.png](attachment:image-2.png)
