# %% [markdown]
# <a href="https://colab.research.google.com/github/moshein/for_practice_-/blob/main/linked_list_exercise_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prob 1

# %%
### copied from class' discussion about linked list

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None
    
    def append(self, data):
        new_node = Node(data)

        if not self.head:
            self.head = new_node
            return
        
        temp = self.head

        while temp.next:
            temp = temp.next
        
        temp.next = new_node

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
    
class LinkedList:
    def __init__(self):
        self.head = None
    
    def append(self, data):
        print("=== APPEND START ===")
        print(f"Passed 1: Creating new node -> this is '[{data}]' \n")

        new_node = Node(data)

        if not self.head:
            print("Passed 2: List is empty")
            print(f"    Setting head -> '[{new_node.data}]' node")

            self.head = new_node

            print("=== APPEND END === \n")
            print("==================================================")
            
            return
        
        print("Passed 2: List is NOT empty")
        temp = self.head
        print(f"    Starting traversal from head -> [{temp.data}] node")

        step = 1

        while temp.next:
            print(f"    Step [{step}]: [{temp.data}] node -> moving to [{temp.next.data}] node")
            temp = temp.next
            step += 1
        
        print(f"Passed 3: Reached last node -> [{temp.data}] node")
        print(f"    Linking [{temp.data}] node -> next to [{new_node.data}] node")
        
        temp.next = new_node

        print("=== APPEND END === \n")
        print("==================================================")

# %%
ll = LinkedList()

ll.append("miku")
ll.append("hatsune")
ll.append("Jesus")
# Out:
# === APPEND START ===
# Passed 1: Creating new node -> this is '[miku]'
#
# Passed 2: List is empty
#     Setting head -> '[miku]' node
# === APPEND END ===
#
# ...
# === APPEND START ===
# Passed 1: Creating new node -> this is '[hatsune]'
#
# Passed 2: List is NOT empty
#     Starting traversal from head -> [miku] node
# Passed 3: Reached last node -> [miku] node
#     Linking [miku] node -> next to [hatsune] node
# === APPEND END ===
#
# ...
# === APPEND START ===
# Passed 1: Creating new node -> this is '[Jesus]'
#
# Passed 2: List is NOT empty
#     Starting traversal from head -> [miku] node
#     Step [1]: [miku] node -> moving to [hatsune] node
# Passed 3: Reached last node -> [hatsune] node
#     Linking [hatsune] node -> next to [Jesus] node
# === APPEND END ===
#
# ...

# %% [markdown]
# # Prob 2
# ## trial 1

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
    

class LinkedList:
    def __init__(self):
        self.head = None
    
    def append(self, data):
        new_node = Node(data)

        if not self.head:
            new_node = self.head ### trial 1: switched their places. what will happen kaya?
            return
        
        temp = self.head

        step = 1

        while temp.next:
            temp = temp.next
            step += 1
        
        temp.next = new_node

    def display(self):
        temp = self.head

        while temp:
            print(temp.data, end="  ->  ")
            temp = temp.next

# %%
ll = LinkedList()

ll.append("miku")
ll.append("Jesus")
ll.append("hatsune")

# %%
ll.display()

# %%
## walay ni display huahuahuha

# %%
class Node:
    def __init__(self, data):
        print(f"[Node Created] this is '[{data}]' node")
        self.data = data
        self.next = None
    

class LinkedList:
    def __init__(self):
        self.head = None
    
    def append(self, data):
        print("=== APPEND START ===")

        print(f"Passed 1: Creating new node -> this is '[{data}]' node")
        new_node = Node(data)

        if not self.head:
            print("Passed 2: List is empty")
            print("  ⚠️ Trial line: new_node = self.head")

            new_node = self.head  # your trial

            print(f"  After assignment:")
            print(f"    new_node is now = [{new_node}]")
            print(f"    head is still = [{self.head}]")
            print("  ❌ We LOST the new node here")

            print("=== APPEND END ===\n")
            return
        
        temp = self.head
        print(f"Passed 2: Traversing from head '[{temp.data}]'")

        step = 1
        while temp.next:
            print(f"  Step [{step}]: at '[{temp.data}]', moving to '[{temp.next.data}]'")
            temp = temp.next
            step += 1
        
        print(f"Passed 3: Last node is '[{temp.data}]'")
        print(f"  Linking '[{temp.data}]' → '[{new_node.data}]'")

        temp.next = new_node

        print("=== APPEND END ===\n")


    def display(self):
        print("=== DISPLAY START ===")
        temp = self.head

        if not temp:
            print("  List is empty 😭")
        
        while temp:
            print(f"[Node: [{temp.data}] → ", end="")
            temp = temp.next
        
        print("None")
        print("=== DISPLAY END ===\n")

# %%
ll = LinkedList()

ll.append("miku")
ll.append("Jesus")
ll.append("Kirisuto-sama")

ll.display()
# Out:
# === APPEND START ===
# Passed 1: Creating new node -> this is '[miku]' node
# [Node Created] this is '[miku]' node
# Passed 2: List is empty
#   ⚠️ Trial line: new_node = self.head
#   After assignment:
#     new_node is now = [None]
#     head is still = [None]
#   ❌ We LOST the new node here
# === APPEND END ===
#
# === APPEND START ===
# Passed 1: Creating new node -> this is '[Jesus]' node
# [Node Created] this is '[Jesus]' node
# Passed 2: List is empty
#   ⚠️ Trial line: new_node = self.head
#   After assignment:
#     new_node is now = [None]
#     head is still = [None]
#   ❌ We LOST the new node here
# === APPEND END ===
#
# === APPEND START ===
# Passed 1: Creating new node -> this is '[Kirisuto-sama]' node
# [Node Created] this is '[Kirisuto-sama]' node
# Passed 2: List is empty
#   ⚠️ Trial line: new_node = self.head
#   After assignment:
#     new_node is now = [None]
#     head is still = [None]
#   ❌ We LOST the new node here
# === APPEND END ===
#
# ...

# %% [markdown]
# ### Explanation
# ![image.png](attachment:image.png)
# (copy pasted this pic lungz rawrawr)

# %% [markdown]
# # Prob 3
# ## trial 2 ig?
# kay dili pa gyapon nako ma-100% click HUHUHHASKJDFHSJKDFHSJAF

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None
    
    def append(self, data):
        new_node = Node(data)

        if not self.head:
            self.head = new_node
            return
        
        ### new question... 
        ### why we named the new node as [temp] and not retain it as [new_node]?

        temp = self.head

        while temp.next:
            temp = temp.next
        
        temp.next = new_node ## is it because para ani? para dili sya libog?

        ### issa becuz [temp] is the travelerr

# %% [markdown]
# ![image.png](attachment:image.png)
