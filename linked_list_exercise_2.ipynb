# %% [markdown]
# <a href="https://colab.research.google.com/github/moshein/for_practice_-/blob/main/linked_list_exercise_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### copied from class' discussion about linked list

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None
    
    def append(self, data):
        new_node = Node(data)

        if not self.head:
            self.head = new_node
            return
        
        temp = self.head

        while temp.next:
            temp = temp.next
        
        temp.next = new_node

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
    
class LinkedList:
    def __init__(self):
        self.head = None
    
    def append(self, data):
        print("=== APPEND START ===")
        print(f"Passed 1: Creating new node -> this is '[{data}]' \n")

        new_node = Node(data)

        if not self.head:
            print("Passed 2: List is empty")
            print(f"    Setting head -> '[{new_node.data}]' node")

            self.head = new_node

            print("=== APPEND END === \n")
            print("==================================================")
            
            return
        
        print("Passed 2: List is NOT empty")
        temp = self.head
        print(f"    Starting traversal from head -> [{temp.data}] node")

        step = 1

        while temp.next:
            print(f"    Step [{step}]: [{temp.data}] node -> moving to [{temp.next.data}] node")
            temp = temp.next
            step += 1
        
        print(f"Passed 3: Reached last node -> [{temp.data}] node")
        print(f"    Linking [{temp.data}] node -> next to [{new_node.data}] node")
        
        temp.next = new_node

        print("=== APPEND END === \n")
        print("==================================================")

# %%
ll = LinkedList()

ll.append("miku")
ll.append("hatsune")
ll.append("Jesus")
# Out:
# === APPEND START ===
# Passed 1: Creating new node -> this is '[miku]'
#
# Passed 2: List is empty
#     Setting head -> '[miku]' node
# === APPEND END ===
#
# ...
# === APPEND START ===
# Passed 1: Creating new node -> this is '[hatsune]'
#
# Passed 2: List is NOT empty
#     Starting traversal from head -> [miku] node
# Passed 3: Reached last node -> [miku] node
#     Linking [miku] node -> next to [hatsune] node
# === APPEND END ===
#
# ...
# === APPEND START ===
# Passed 1: Creating new node -> this is '[Jesus]'
#
# Passed 2: List is NOT empty
#     Starting traversal from head -> [miku] node
#     Step [1]: [miku] node -> moving to [hatsune] node
# Passed 3: Reached last node -> [hatsune] node
#     Linking [hatsune] node -> next to [Jesus] node
# === APPEND END ===
#
# ...
